# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Hiba\\Desktop\\data set\\ml'

# %%
os.chdir('C:/Users/Hiba/Desktop/data set/ml')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Hiba\\Desktop\\data set\\ml'

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing 
import matplotlib.pyplot as plt
# %matplotlib inline
data1=pd.read_csv("airquality.csv")
data1
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 0     41.0    190.0   7.4    67      5    1
# 1     36.0    118.0   8.0    72      5    2
# 2     12.0    149.0  12.6    74      5    3
# 3     18.0    313.0  11.5    62      5    4
# 4      NaN      NaN  14.3    56      5    5
# 5     28.0      NaN  14.9    66      5    6
# 6     23.0    299.0   8.6    65      5    7
# 7     19.0     99.0  13.8    59      5    8
# 8      8.0     19.0  20.1    61      5    9
# 9      NaN    194.0   8.6    69      5   10
# 10     7.0      NaN   6.9    74      5   11
# 11    16.0    256.0   9.7    69      5   12
# 12    11.0    290.0   9.2    66      5   13
# 13    14.0    274.0  10.9    68      5   14
# 14    18.0     65.0  13.2    58      5   15
# 15    14.0    334.0  11.5    64      5   16
# 16    34.0    307.0  12.0    66      5   17
# 17     6.0     78.0  18.4    57      5   18
# 18    30.0    322.0  11.5    68      5   19
# 19    11.0     44.0   9.7    62      5   20
# ...

# %%
data1.shape
# Out:
# (153, 6)

# %%
#Get a count of missing values in a dataset
data1.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# Ozone      37
# Solar.R     7
# Wind        0
# Temp        0
# Month       0
# Day         0
# dtype: int64

# %%
features=data1.iloc[:,1:].values
features
# Out:
# array([[190. ,   7.4,  67. ,   5. ,   1. ],
#        [118. ,   8. ,  72. ,   5. ,   2. ],
#        [149. ,  12.6,  74. ,   5. ,   3. ],
#        [313. ,  11.5,  62. ,   5. ,   4. ],
#        [  nan,  14.3,  56. ,   5. ,   5. ],
#        [  nan,  14.9,  66. ,   5. ,   6. ],
#        [299. ,   8.6,  65. ,   5. ,   7. ],
#        [ 99. ,  13.8,  59. ,   5. ,   8. ],
#        [ 19. ,  20.1,  61. ,   5. ,   9. ],
#        [194. ,   8.6,  69. ,   5. ,  10. ],
#        [  nan,   6.9,  74. ,   5. ,  11. ],
#        [256. ,   9.7,  69. ,   5. ,  12. ],
#        [290. ,   9.2,  66. ,   5. ,  13. ],
#        [274. ,  10.9,  68. ,   5. ,  14. ],
#        [ 65. ,  13.2,  58. ,   5. ,  15. ],
#        [334. ,  11.5,  64. ,   5. ,  16. ],
#        [307. ,  12. ,  66. ,   5. ,  17. ],
#        [ 78. ,  18.4,  57. ,   5. ,  18. ],
#        [322. ,  11.5,  68. ,   5. ,  19. ],
#        [ 44. ,   9.7,  62. ,   5. ,  20. ],
#        [  8. ,   9.7,  59. ,   5. ,  21. ],
# ...

# %%
labels=data1.iloc[:,:1].values
labels
# Out:
# array([[ 41.],
#        [ 36.],
#        [ 12.],
#        [ 18.],
#        [ nan],
#        [ 28.],
#        [ 23.],
#        [ 19.],
#        [  8.],
#        [ nan],
#        [  7.],
#        [ 16.],
#        [ 11.],
#        [ 14.],
#        [ 18.],
#        [ 14.],
#        [ 34.],
#        [  6.],
#        [ 30.],
#        [ 11.],
#        [  1.],
#        [ 11.],
#        [  4.],
#        [ 32.],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ 23.],
#        [ 45.],
#        [115.],
#        [ 37.],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ 29.],
#        [ nan],
#        [ 71.],
#        [ 39.],
#        [ nan],
#        [ nan],
#        [ 23.],
#        [ nan],
#        [ nan],
#        [ 21.],
#        [ 37.],
#        [ 20.],
#        [ 12.],
#        [ 13.],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
#        [ nan],
# ...

# %%
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values='NaN',strategy='mean',axis=0) 
#imputer doesnt work on categorical data but we can recode the categorical data

# %%
imputer.fit(features[:,[0,1]])
features[:,[0,1]]=imputer.fit_transform(features[:,[0,1]])

# %%
df1=pd.DataFrame(features)

# %%
df1.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %%
df1
# Out:
#               0     1     2    3     4
# 0    190.000000   7.4  67.0  5.0   1.0
# 1    118.000000   8.0  72.0  5.0   2.0
# 2    149.000000  12.6  74.0  5.0   3.0
# 3    313.000000  11.5  62.0  5.0   4.0
# 4    185.931507  14.3  56.0  5.0   5.0
# 5    185.931507  14.9  66.0  5.0   6.0
# 6    299.000000   8.6  65.0  5.0   7.0
# 7     99.000000  13.8  59.0  5.0   8.0
# 8     19.000000  20.1  61.0  5.0   9.0
# 9    194.000000   8.6  69.0  5.0  10.0
# 10   185.931507   6.9  74.0  5.0  11.0
# 11   256.000000   9.7  69.0  5.0  12.0
# 12   290.000000   9.2  66.0  5.0  13.0
# 13   274.000000  10.9  68.0  5.0  14.0
# 14    65.000000  13.2  58.0  5.0  15.0
# 15   334.000000  11.5  64.0  5.0  16.0
# 16   307.000000  12.0  66.0  5.0  17.0
# 17    78.000000  18.4  57.0  5.0  18.0
# 18   322.000000  11.5  68.0  5.0  19.0
# 19    44.000000   9.7  62.0  5.0  20.0
# 20     8.000000   9.7  59.0  5.0  21.0
# 21   320.000000  16.6  73.0  5.0  22.0
# 22    25.000000   9.7  61.0  5.0  23.0
# ...

# %%
imputer.fit(labels[:,[0]])
labels[:,[0]]=imputer.fit_transform(labels[:,[0]])

# %%
df2=pd.DataFrame(labels)

# %%
df2.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# 0    0
# dtype: int64

# %%
df2
# Out:
#              0
# 0     41.00000
# 1     36.00000
# 2     12.00000
# 3     18.00000
# 4     42.12931
# 5     28.00000
# 6     23.00000
# 7     19.00000
# 8      8.00000
# 9     42.12931
# 10     7.00000
# 11    16.00000
# 12    11.00000
# 13    14.00000
# 14    18.00000
# 15    14.00000
# 16    34.00000
# 17     6.00000
# 18    30.00000
# 19    11.00000
# 20     1.00000
# 21    11.00000
# 22     4.00000
# 23    32.00000
# 24    42.12931
# 25    42.12931
# 26    42.12931
# 27    23.00000
# 28    45.00000
# 29   115.00000
# ..         ...
# 123   96.00000
# 124   78.00000
# 125   73.00000
# 126   91.00000
# 127   47.00000
# 128   32.00000
# 129   20.00000
# 130   23.00000
# 131   21.00000
# 132   24.00000
# 133   44.00000
# 134   21.00000
# 135   28.00000
# 136    9.00000
# 137   13.00000
# 138   46.00000
# 139   18.00000
# 140   13.00000
# 141   24.00000
# 142   16.00000
# 143   13.00000
# 144   23.00000
# 145   36.00000
# 146    7.00000
# 147   14.00000
# 148   30.00000
# ...

# %%
#Assign ozone values to an object
Ozone=df2[0]
Ozone
# Out:
# 0       41.00000
# 1       36.00000
# 2       12.00000
# 3       18.00000
# 4       42.12931
# 5       28.00000
# 6       23.00000
# 7       19.00000
# 8        8.00000
# 9       42.12931
# 10       7.00000
# 11      16.00000
# 12      11.00000
# 13      14.00000
# 14      18.00000
# 15      14.00000
# 16      34.00000
# 17       6.00000
# 18      30.00000
# 19      11.00000
# 20       1.00000
# 21      11.00000
# 22       4.00000
# 23      32.00000
# 24      42.12931
# 25      42.12931
# 26      42.12931
# 27      23.00000
# 28      45.00000
# 29     115.00000
#          ...
# 123     96.00000
# 124     78.00000
# 125     73.00000
# 126     91.00000
# 127     47.00000
# 128     32.00000
# 129     20.00000
# 130     23.00000
# 131     21.00000
# 132     24.00000
# 133     44.00000
# 134     21.00000
# 135     28.00000
# 136      9.00000
# 137     13.00000
# 138     46.00000
# 139     18.00000
# 140     13.00000
# 141     24.00000
# 142     16.00000
# 143     13.00000
# ...

# %%
wind=data1['Wind']
wind
# Out:
# 0       7.4
# 1       8.0
# 2      12.6
# 3      11.5
# 4      14.3
# 5      14.9
# 6       8.6
# 7      13.8
# 8      20.1
# 9       8.6
# 10      6.9
# 11      9.7
# 12      9.2
# 13     10.9
# 14     13.2
# 15     11.5
# 16     12.0
# 17     18.4
# 18     11.5
# 19      9.7
# 20      9.7
# 21     16.6
# 22      9.7
# 23     12.0
# 24     16.6
# 25     14.9
# 26      8.0
# 27     12.0
# 28     14.9
# 29      5.7
#        ...
# 123     6.9
# 124     5.1
# 125     2.8
# 126     4.6
# 127     7.4
# 128    15.5
# 129    10.9
# 130    10.3
# 131    10.9
# 132     9.7
# 133    14.9
# 134    15.5
# 135     6.3
# 136    10.9
# 137    11.5
# 138     6.9
# 139    13.8
# 140    10.3
# 141    10.3
# 142     8.0
# 143    12.6
# 144     9.2
# 145    10.3
# 146    10.3
# 147    16.6
# 148     6.9
# 149    13.2
# 150    14.3
# 151     8.0
# 152    11.5
# Name: Wind, Length: 153, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(wind,Ozone,'o')
plt.ylabel("Ozone")
plt.xlabel("Wind")
# Out:
# Text(0.5,0,'Wind')

# %%
data1.boxplot(column='Ozone',by='Wind')

# %%
data1.corr()
# Out:
#             Ozone   Solar.R      Wind      Temp     Month       Day
# Ozone    1.000000  0.348342 -0.601547  0.698360  0.164519  0.004790
# Solar.R  0.348342  1.000000 -0.056792  0.275840 -0.075301 -0.159169
# Wind    -0.601547 -0.056792  1.000000 -0.457988 -0.178293  0.018440
# Temp     0.698360  0.275840 -0.457988  1.000000  0.420947 -0.109867
# Month    0.164519 -0.075301 -0.178293  0.420947  1.000000 -0.036411
# Day      0.004790 -0.159169  0.018440 -0.109867 -0.036411  1.000000

# %%
data1.cov()
# Out:
#                Ozone      Solar.R       Wind        Temp     Month         Day
# Ozone    1088.200525  1056.583456 -70.938531  218.521214  8.008921    1.378036
# Solar.R  1056.583456  8110.519414 -17.945971  229.159754 -9.522248 -125.928389
# Wind      -70.938531   -17.945971  12.411539  -15.272136 -0.889753    0.574858
# Temp      218.521214   229.159754 -15.272136   89.591331  5.643963   -9.202012
# Month       8.008921    -9.522248  -0.889753    5.643963  2.006536   -0.456398
# Day         1.378036  -125.928389   0.574858   -9.202012 -0.456398   78.301084

# %%
mean_Ozone=data1['Ozone'].mean()

# %%
mean_Ozone
# Out:
# 42.12931034482759

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(wind,Ozone,'o')
plt.ylabel("Ozone")
plt.xlabel("Wind")
plt.axhline(mean_Ozone,color='r',linestyle='-')
plt.show()

# %%
import statsmodels.api as sm
model=sm.OLS(Ozone,wind).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.464
# Model:                            OLS   Adj. R-squared:                  0.460
# Method:                 Least Squares   F-statistic:                     131.5
# Date:                Thu, 03 Oct 2019   Prob (F-statistic):           2.49e-22
# Time:                        21:01:47   Log-Likelihood:                -770.73
# No. Observations:                 153   AIC:                             1543.
# Df Residuals:                     152   BIC:                             1546.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Wind           3.2847      0.286     11.469      0.000       2.719       3.851
# ...

# %%
#Seaborn 
import seaborn as sns
sns.pairplot(df1)

# %%
sns.distplot(data1['Wind'])
# Out:
# C:\Users\Hiba\Anaconda3\New folder\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
corr=data1.corr() #black color=-ve correlation
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)

# %%
plt.plot(wind,Ozone,'o')
plt.ylabel("Ozone")
plt.xlabel("Wind")
plt.axhline(mean_Ozone,color='r',linestyle='-')
sns.regplot(x='Wind',y='Ozone',data=data1)
plt.show()
# Out:
# C:\Users\Hiba\Anaconda3\New folder\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
X=data1['Wind'] #splitting data
y=df2[0]

# %%
X
# Out:
# 0       7.4
# 1       8.0
# 2      12.6
# 3      11.5
# 4      14.3
# 5      14.9
# 6       8.6
# 7      13.8
# 8      20.1
# 9       8.6
# 10      6.9
# 11      9.7
# 12      9.2
# 13     10.9
# 14     13.2
# 15     11.5
# 16     12.0
# 17     18.4
# 18     11.5
# 19      9.7
# 20      9.7
# 21     16.6
# 22      9.7
# 23     12.0
# 24     16.6
# 25     14.9
# 26      8.0
# 27     12.0
# 28     14.9
# 29      5.7
#        ...
# 123     6.9
# 124     5.1
# 125     2.8
# 126     4.6
# 127     7.4
# 128    15.5
# 129    10.9
# 130    10.3
# 131    10.9
# 132     9.7
# 133    14.9
# 134    15.5
# 135     6.3
# 136    10.9
# 137    11.5
# 138     6.9
# 139    13.8
# 140    10.3
# 141    10.3
# 142     8.0
# 143    12.6
# 144     9.2
# 145    10.3
# 146    10.3
# 147    16.6
# 148     6.9
# 149    13.2
# 150    14.3
# 151     8.0
# 152    11.5
# Name: Wind, Length: 153, dtype: float64

# %%
y
# Out:
# 0       41.00000
# 1       36.00000
# 2       12.00000
# 3       18.00000
# 4       42.12931
# 5       28.00000
# 6       23.00000
# 7       19.00000
# 8        8.00000
# 9       42.12931
# 10       7.00000
# 11      16.00000
# 12      11.00000
# 13      14.00000
# 14      18.00000
# 15      14.00000
# 16      34.00000
# 17       6.00000
# 18      30.00000
# 19      11.00000
# 20       1.00000
# 21      11.00000
# 22       4.00000
# 23      32.00000
# 24      42.12931
# 25      42.12931
# 26      42.12931
# 27      23.00000
# 28      45.00000
# 29     115.00000
#          ...
# 123     96.00000
# 124     78.00000
# 125     73.00000
# 126     91.00000
# 127     47.00000
# 128     32.00000
# 129     20.00000
# 130     23.00000
# 131     21.00000
# 132     24.00000
# 133     44.00000
# 134     21.00000
# 135     28.00000
# 136      9.00000
# 137     13.00000
# 138     46.00000
# 139     18.00000
# 140     13.00000
# 141     24.00000
# 142     16.00000
# 143     13.00000
# ...

# %%
x=df1.loc[:,[2]]
x
# Out:
#         2
# 0    67.0
# 1    72.0
# 2    74.0
# 3    62.0
# 4    56.0
# 5    66.0
# 6    65.0
# 7    59.0
# 8    61.0
# 9    69.0
# 10   74.0
# 11   69.0
# 12   66.0
# 13   68.0
# 14   58.0
# 15   64.0
# 16   66.0
# 17   57.0
# 18   68.0
# 19   62.0
# 20   59.0
# 21   73.0
# 22   61.0
# 23   61.0
# 24   57.0
# 25   58.0
# 26   57.0
# 27   67.0
# 28   81.0
# 29   79.0
# ..    ...
# 123  91.0
# 124  92.0
# 125  93.0
# 126  93.0
# 127  87.0
# 128  84.0
# 129  80.0
# 130  78.0
# 131  75.0
# 132  73.0
# 133  81.0
# 134  76.0
# 135  77.0
# 136  71.0
# 137  71.0
# 138  78.0
# 139  67.0
# 140  76.0
# 141  68.0
# 142  82.0
# 143  64.0
# 144  71.0
# 145  81.0
# 146  69.0
# 147  63.0
# 148  70.0
# 149  77.0
# 150  75.0
# 151  76.0
# 152  68.0
#
# [153 rows x 1 columns]

# %%
x.describe()
# Out:
#                 2
# count  153.000000
# mean    77.882353
# std      9.465270
# min     56.000000
# 25%     72.000000
# 50%     79.000000
# 75%     85.000000
# max     97.000000

# %%
minmax=preprocessing.MinMaxScaler(feature_range=(0,1))
N=minmax.fit(x).transform(x)
N
# Out:
# array([[0.26829268],
#        [0.3902439 ],
#        [0.43902439],
#        [0.14634146],
#        [0.        ],
#        [0.24390244],
#        [0.2195122 ],
#        [0.07317073],
#        [0.12195122],
#        [0.31707317],
#        [0.43902439],
#        [0.31707317],
#        [0.24390244],
#        [0.29268293],
#        [0.04878049],
#        [0.19512195],
#        [0.24390244],
#        [0.02439024],
#        [0.29268293],
#        [0.14634146],
#        [0.07317073],
#        [0.41463415],
#        [0.12195122],
#        [0.12195122],
#        [0.02439024],
#        [0.04878049],
#        [0.02439024],
#        [0.26829268],
#        [0.6097561 ],
#        [0.56097561],
#        [0.48780488],
#        [0.53658537],
#        [0.43902439],
#        [0.26829268],
#        [0.68292683],
#        [0.70731707],
#        [0.56097561],
#        [0.63414634],
#        [0.75609756],
#        [0.82926829],
#        [0.75609756],
#        [0.90243902],
#        [0.87804878],
# ...

# %%
#Split data into training set and test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=1) #split the data into training and test set

# %%
x_train
# Out:
# 136    10.9
# 11      9.7
# 114    12.6
# 2      12.6
# 105     9.7
# 6       8.6
# 0       7.4
# 111    10.3
# 65      4.6
# 55      8.0
# 104    11.5
# 135     6.3
# 46     14.9
# 62      9.2
# 74     14.9
# 117     8.0
# 94      7.4
# 151     8.0
# 90      7.4
# 10      6.9
# 34      9.2
# 32      9.7
# 125     2.8
# 38      6.9
# 83     11.5
# 112    15.5
# 152    11.5
# 27     12.0
# 23     12.0
# 67      5.1
#        ...
# 13     10.9
# 88      7.4
# 8      20.1
# 81      6.9
# 60      8.0
# 128    15.5
# 1       8.0
# 57     10.3
# 22      9.7
# 61      4.1
# 63      9.2
# 7      13.8
# 86      8.6
# 96      7.4
# 68      6.3
# 50     10.3
# 139    13.8
# 101     8.6
# 20      9.7
# 25     14.9
# 134    15.5
# 71      8.6
# 129    10.9
# 144     9.2
# 79      5.1
# 133    14.9
# 137    11.5
# 72     14.3
# 140    10.3
# 37      9.7
# Name: Wind, Length: 91, dtype: float64

# %%
y_train
# Out:
# 136      9.00000
# 11      16.00000
# 114     42.12931
# 2       12.00000
# 105     65.00000
# 6       23.00000
# 0       41.00000
# 111     44.00000
# 65      64.00000
# 55      42.12931
# 104     28.00000
# 135     28.00000
# 46      21.00000
# 62      49.00000
# 74      42.12931
# 117     73.00000
# 94      16.00000
# 151     18.00000
# 90      64.00000
# 10       7.00000
# 34      42.12931
# 32      42.12931
# 125     73.00000
# 38      42.12931
# 83      42.12931
# 112     21.00000
# 152     20.00000
# 27      23.00000
# 23      32.00000
# 67      77.00000
#          ...
# 13      14.00000
# 88      82.00000
# 8        8.00000
# 81      16.00000
# 60      42.12931
# 128     32.00000
# 1       36.00000
# 57      42.12931
# 22       4.00000
# 61     135.00000
# 63      32.00000
# 7       19.00000
# 86      20.00000
# 96      35.00000
# 68      97.00000
# 50      13.00000
# 139     18.00000
# 101     42.12931
# 20       1.00000
# 25      42.12931
# 134     21.00000
# ...

# %%
x_test
# Out:
# 59     14.9
# 33     16.1
# 69      5.7
# 127     7.4
# 31      8.6
# 107    10.3
# 97      4.6
# 14     13.2
# 53      4.6
# 44     13.8
# 147    16.6
# 138     6.9
# 78      6.3
# 102    11.5
# 5      14.9
# 85      8.0
# 16     12.0
# 100     8.0
# 89      7.4
# 95      6.9
# 91      9.2
# 124     5.1
# 92      6.9
# 99     10.3
# 93     13.8
# 40     11.5
# 29      5.7
# 42      9.2
# 54      6.3
# 122     6.3
#        ...
# 113    14.3
# 103    11.5
# 77     10.3
# 145    10.3
# 58     11.5
# 121     6.3
# 56      8.0
# 28     14.9
# 51      6.3
# 109     7.4
# 66     10.9
# 17     18.4
# 119     9.7
# 126     4.6
# 132     9.7
# 73     14.9
# 18     11.5
# 48      9.2
# 4      14.3
# 45     11.5
# 75     14.3
# 39     13.8
# 36     14.3
# 118     5.7
# 141    10.3
# 108     6.3
# 12      9.2
# 148     6.9
# 84      8.6
# 123     6.9
# Name: Wind, Length: 62, dtype: float64

# %%
y_test
# Out:
# 59      42.12931
# 33      42.12931
# 69      97.00000
# 127     47.00000
# 31      42.12931
# 107     22.00000
# 97      66.00000
# 14      18.00000
# 53      42.12931
# 44      42.12931
# 147     14.00000
# 138     46.00000
# 78      61.00000
# 102     42.12931
# 5       28.00000
# 85     108.00000
# 16      34.00000
# 100    110.00000
# 89      50.00000
# 95      78.00000
# 91      59.00000
# 124     78.00000
# 92      39.00000
# 99      89.00000
# 93       9.00000
# 40      39.00000
# 29     115.00000
# 42      42.12931
# 54      42.12931
# 122     85.00000
#          ...
# 113      9.00000
# 103     44.00000
# 77      35.00000
# 145     36.00000
# 58      42.12931
# 121     84.00000
# 56      42.12931
# 28      45.00000
# 51      42.12931
# 109     23.00000
# 66      40.00000
# 17       6.00000
# 119     76.00000
# 126     91.00000
# 132     24.00000
# 73      27.00000
# 18      30.00000
# 48      20.00000
# 4       42.12931
# 45      42.12931
# 75       7.00000
# ...

# %%
x_train=x_train.values.reshape((-1,1))
x_train
# Out:
# array([[10.9],
#        [ 9.7],
#        [12.6],
#        [12.6],
#        [ 9.7],
#        [ 8.6],
#        [ 7.4],
#        [10.3],
#        [ 4.6],
#        [ 8. ],
#        [11.5],
#        [ 6.3],
#        [14.9],
#        [ 9.2],
#        [14.9],
#        [ 8. ],
#        [ 7.4],
#        [ 8. ],
#        [ 7.4],
#        [ 6.9],
#        [ 9.2],
#        [ 9.7],
#        [ 2.8],
#        [ 6.9],
#        [11.5],
#        [15.5],
#        [11.5],
#        [12. ],
#        [12. ],
#        [ 5.1],
#        [ 8.6],
#        [10.9],
#        [ 4. ],
#        [ 2.3],
#        [12.6],
#        [12. ],
#        [ 8. ],
#        [10.9],
#        [10.9],
#        [11.5],
#        [ 9.7],
#        [10.9],
#        [11.5],
#        [ 1.7],
#        [ 8. ],
#        [ 6.9],
#        [ 8. ],
#        [16.6],
#        [13.2],
#        [ 3.4],
#        [10.3],
#        [11.5],
#        [16.6],
#        [ 7.4],
#        [11.5],
#        [10.3],
#        [ 7.4],
#        [14.3],
# ...

# %%
from sklearn import  linear_model as lm
model=lm.LinearRegression()
results=model.fit(x_train,y_train)

# %%
accuracy=model.score(x_train,y_train)
print("Accuracy is",accuracy)
# Out:
# Accuracy is 0.28417199201340404

# %%
#print coef
print('intercept',model.intercept_)
print('slope',model.coef_)
#observation- the slope value is 0.051 predicted O_ring_failures increased by 0.05
# Out:
# intercept 82.09503542922556
# slope [-4.35586209]

# %%
#rotate
x_test=x_test.values.reshape((-1,1))

# %%
x_test
# Out:
# array([[14.9],
#        [16.1],
#        [ 5.7],
#        [ 7.4],
#        [ 8.6],
#        [10.3],
#        [ 4.6],
#        [13.2],
#        [ 4.6],
#        [13.8],
#        [16.6],
#        [ 6.9],
#        [ 6.3],
#        [11.5],
#        [14.9],
#        [ 8. ],
#        [12. ],
#        [ 8. ],
#        [ 7.4],
#        [ 6.9],
#        [ 9.2],
#        [ 5.1],
#        [ 6.9],
#        [10.3],
#        [13.8],
#        [11.5],
#        [ 5.7],
#        [ 9.2],
#        [ 6.3],
#        [ 6.3],
#        [ 8.6],
#        [ 9.7],
#        [14.3],
#        [11.5],
#        [10.3],
#        [10.3],
#        [11.5],
#        [ 6.3],
#        [ 8. ],
#        [14.9],
#        [ 6.3],
#        [ 7.4],
#        [10.9],
#        [18.4],
#        [ 9.7],
#        [ 4.6],
#        [ 9.7],
#        [14.9],
#        [11.5],
#        [ 9.2],
#        [14.3],
#        [11.5],
#        [14.3],
#        [13.8],
#        [14.3],
#        [ 5.7],
#        [10.3],
#        [ 6.3],
# ...

# %%
predictions=model.predict(x_test)
print('predicted O.ring.failures',predictions,sep='\n')
# Out:
# predicted O.ring.failures
# [17.19269032 11.96565582 57.26662153 49.86165598 44.63462147 37.22965592
#  62.05806983 24.59765587 62.05806983 21.98413862  9.78772477 52.03958702
#  54.65310428 32.00262142 17.19269032 47.24813873 29.82469038 47.24813873
#  49.86165598 52.03958702 42.02110422 59.88013878 52.03958702 37.22965592
#  21.98413862 32.00262142 57.26662153 42.02110422 54.65310428 54.65310428
#  44.63462147 39.84317318 19.80620757 32.00262142 37.22965592 37.22965592
#  32.00262142 54.65310428 47.24813873 17.19269032 54.65310428 49.86165598
#  34.61613867  1.94717301 39.84317318 62.05806983 39.84317318 17.19269032
#  32.00262142 42.02110422 19.80620757 32.00262142 19.80620757 21.98413862
#  19.80620757 57.26662153 37.22965592 54.65310428 42.02110422 52.03958702
#  44.63462147 52.03958702]

# %%
print(y_test.values)
# Out:
# [ 42.12931034  42.12931034  97.          47.          42.12931034
#   22.          66.          18.          42.12931034  42.12931034
#   14.          46.          61.          42.12931034  28.
#  108.          34.         110.          50.          78.
#   59.          78.          39.          89.           9.
#   39.         115.          42.12931034  42.12931034  85.
#   42.12931034  11.           9.          44.          35.
#   36.          42.12931034  84.          42.12931034  45.
#   42.12931034  23.          40.           6.          76.
#   91.          24.          27.          30.          20.
#   42.12931034  42.12931034   7.          71.          42.12931034
#   42.12931034  24.          59.          11.          30.
#   80.          96.        ]

# %%
plt.scatter(y_test,predictions)

# %%
y_pred=model.intercept_+model.coef_*x_test
print('predicted responsw:',y_pred,sep='\n')
# Out:
# predicted responsw:
# [[17.19269032]
#  [11.96565582]
#  [57.26662153]
#  [49.86165598]
#  [44.63462147]
#  [37.22965592]
#  [62.05806983]
#  [24.59765587]
#  [62.05806983]
#  [21.98413862]
#  [ 9.78772477]
#  [52.03958702]
#  [54.65310428]
#  [32.00262142]
#  [17.19269032]
#  [47.24813873]
#  [29.82469038]
#  [47.24813873]
#  [49.86165598]
#  [52.03958702]
#  [42.02110422]
#  [59.88013878]
#  [52.03958702]
#  [37.22965592]
#  [21.98413862]
#  [32.00262142]
#  [57.26662153]
#  [42.02110422]
#  [54.65310428]
#  [54.65310428]
#  [44.63462147]
#  [39.84317318]
#  [19.80620757]
#  [32.00262142]
#  [37.22965592]
#  [37.22965592]
#  [32.00262142]
#  [54.65310428]
#  [47.24813873]
#  [17.19269032]
#  [54.65310428]
#  [49.86165598]
#  [34.61613867]
#  [ 1.94717301]
#  [39.84317318]
#  [62.05806983]
#  [39.84317318]
#  [17.19269032]
#  [32.00262142]
#  [42.02110422]
#  [19.80620757]
#  [32.00262142]
#  [19.80620757]
#  [21.98413862]
#  [19.80620757]
#  [57.26662153]
#  [37.22965592]
# ...

# %%
#Define new data instance
Xnew=[[5]]
#MAKE a predition
ynew=model.predict(Xnew)

#show inputs nd predicted outputs
print("New wind=%s,Predicted Ozone=%s"%(Xnew,ynew))
# Out:
# New wind=[[5]],Predicted Ozone=[60.31572499]

# %%
Xnew=[[25]]
ynew=model.predict(Xnew)
print("New wind=%s,Predicted Ozone=%s"%(Xnew,ynew))
# Out:
# New wind=[[25]],Predicted Ozone=[-26.80151677]

# %%
#Evaluating the model
from sklearn.metrics import mean_squared_error,r2_score
x_train=x_train.reshape(-1,1)
y_train_prediction=model.predict(x_train)

x_test=x_test.reshape(-1,1)
y_test_prediction=model.predict(x_test)

# %%
#model evaluation for training set

import numpy as np
rmse_training=(np.sqrt(mean_squared_error(y_train,y_train_prediction)))
r2_training=r2_score(y_train,y_train_prediction)

print("The model performance for training set")
print("__________________")
print("RMSE is {}".format(rmse_training))
print('R2 score is {}'.format(r2_training))
print("\n")
# Out:
# The model performance for training set
# __________________
# RMSE is 24.6298402736063
# R2 score is 0.28417199201340404

# %%
#model evaluation for test set
rmse_testing=(np.sqrt(mean_squared_error(y_test,y_test_prediction)))
r2_testing=r2_score(y_test,y_test_prediction)

print("The model performance for testing set")
print("__________________")
print("RMSE is {}".format(rmse_testing))
print('R2 score is {}'.format(r2_testing))
print("\n")
# Out:
# The model performance for testing set
# __________________
# RMSE is 24.24392748897003
# R2 score is 0.1904922565130096

# %%
plt.scatter(X,y)
plt.xlabel('wind')
plt.ylabel('Ozone')
# Out:
# Text(0,0.5,'Ozone')

# %%
X=X.reshape(-1,1)
y_predicted=model.predict(X)
# Out:
# C:\Users\Hiba\Anaconda3\New folder\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   """Entry point for launching an IPython kernel.

# %%
y_predicted
# Out:
# array([49.86165598, 47.24813873, 27.21117312, 32.00262142, 19.80620757,
#        17.19269032, 44.63462147, 21.98413862, -5.45779254, 44.63462147,
#        52.03958702, 39.84317318, 42.02110422, 34.61613867, 24.59765587,
#        32.00262142, 29.82469038,  1.94717301, 32.00262142, 39.84317318,
#        39.84317318,  9.78772477, 39.84317318, 29.82469038,  9.78772477,
#        17.19269032, 47.24813873, 29.82469038, 17.19269032, 57.26662153,
#        49.86165598, 44.63462147, 39.84317318, 11.96565582, 42.02110422,
#        44.63462147, 19.80620757, 39.84317318, 52.03958702, 21.98413862,
#        32.00262142, 34.61613867, 42.02110422, 47.24813873, 21.98413862,
#        32.00262142, 17.19269032, -8.07130979, 42.02110422, 32.00262142,
#        37.22965592, 54.65310428, 74.69006988, 62.05806983, 54.65310428,
#        47.24813873, 47.24813873, 37.22965592, 32.00262142, 17.19269032,
#        47.24813873, 64.23600087, 42.02110422, 42.02110422, 34.61613867,
# ...

# %%
plt.plot(X,y_predicted,color='r')
plt.show()

# %% [markdown]
# # Multiple regression

# %%
X=data1[["Wind","Temp"]]
y=df2[0]

model1=sm.OLS(y,X).fit()
predictions=model1.predict(X)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.822
# Model:                            OLS   Adj. R-squared:                  0.819
# Method:                 Least Squares   F-statistic:                     347.6
# Date:                Thu, 03 Oct 2019   Prob (F-statistic):           3.08e-57
# Time:                        21:01:57   Log-Likelihood:                -686.58
# No. Observations:                 153   AIC:                             1377.
# Df Residuals:                     151   BIC:                             1383.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Wind          -3.3877      0.418     -8.108      0.000      -4.213      -2.562
# ...

# %%
x=df1.loc[:,[2,3]]
x
# Out:
#         2    3
# 0    67.0  5.0
# 1    72.0  5.0
# 2    74.0  5.0
# 3    62.0  5.0
# 4    56.0  5.0
# 5    66.0  5.0
# 6    65.0  5.0
# 7    59.0  5.0
# 8    61.0  5.0
# 9    69.0  5.0
# 10   74.0  5.0
# 11   69.0  5.0
# 12   66.0  5.0
# 13   68.0  5.0
# 14   58.0  5.0
# 15   64.0  5.0
# 16   66.0  5.0
# 17   57.0  5.0
# 18   68.0  5.0
# 19   62.0  5.0
# 20   59.0  5.0
# 21   73.0  5.0
# 22   61.0  5.0
# 23   61.0  5.0
# 24   57.0  5.0
# 25   58.0  5.0
# 26   57.0  5.0
# 27   67.0  5.0
# 28   81.0  5.0
# 29   79.0  5.0
# ..    ...  ...
# 123  91.0  9.0
# 124  92.0  9.0
# 125  93.0  9.0
# 126  93.0  9.0
# 127  87.0  9.0
# 128  84.0  9.0
# 129  80.0  9.0
# 130  78.0  9.0
# 131  75.0  9.0
# 132  73.0  9.0
# 133  81.0  9.0
# 134  76.0  9.0
# 135  77.0  9.0
# 136  71.0  9.0
# 137  71.0  9.0
# 138  78.0  9.0
# 139  67.0  9.0
# 140  76.0  9.0
# 141  68.0  9.0
# 142  82.0  9.0
# 143  64.0  9.0
# 144  71.0  9.0
# 145  81.0  9.0
# 146  69.0  9.0
# 147  63.0  9.0
# 148  70.0  9.0
# ...

# %%
x.describe()
# Out:
#                 2           3
# count  153.000000  153.000000
# mean    77.882353    6.993464
# std      9.465270    1.416522
# min     56.000000    5.000000
# 25%     72.000000    6.000000
# 50%     79.000000    7.000000
# 75%     85.000000    8.000000
# max     97.000000    9.000000

# %%
minmax=preprocessing.MinMaxScaler(feature_range=(0,1))
N=minmax.fit(x).transform(x)
N
# Out:
# array([[0.26829268, 0.        ],
#        [0.3902439 , 0.        ],
#        [0.43902439, 0.        ],
#        [0.14634146, 0.        ],
#        [0.        , 0.        ],
#        [0.24390244, 0.        ],
#        [0.2195122 , 0.        ],
#        [0.07317073, 0.        ],
#        [0.12195122, 0.        ],
#        [0.31707317, 0.        ],
#        [0.43902439, 0.        ],
#        [0.31707317, 0.        ],
#        [0.24390244, 0.        ],
#        [0.29268293, 0.        ],
#        [0.04878049, 0.        ],
#        [0.19512195, 0.        ],
#        [0.24390244, 0.        ],
#        [0.02439024, 0.        ],
#        [0.29268293, 0.        ],
#        [0.14634146, 0.        ],
#        [0.07317073, 0.        ],
#        [0.41463415, 0.        ],
#        [0.12195122, 0.        ],
#        [0.12195122, 0.        ],
#        [0.02439024, 0.        ],
#        [0.04878049, 0.        ],
#        [0.02439024, 0.        ],
#        [0.26829268, 0.        ],
# ...

# %%
y=df1.iloc[:,0]
y
# Out:
# 0      190.000000
# 1      118.000000
# 2      149.000000
# 3      313.000000
# 4      185.931507
# 5      185.931507
# 6      299.000000
# 7       99.000000
# 8       19.000000
# 9      194.000000
# 10     185.931507
# 11     256.000000
# 12     290.000000
# 13     274.000000
# 14      65.000000
# 15     334.000000
# 16     307.000000
# 17      78.000000
# 18     322.000000
# 19      44.000000
# 20       8.000000
# 21     320.000000
# 22      25.000000
# 23      92.000000
# 24      66.000000
# 25     266.000000
# 26     185.931507
# 27      13.000000
# 28     252.000000
# 29     223.000000
#           ...
# 123    167.000000
# 124    197.000000
# 125    183.000000
# 126    189.000000
# 127     95.000000
# 128     92.000000
# 129    252.000000
# 130    220.000000
# 131    230.000000
# 132    259.000000
# 133    236.000000
# 134    259.000000
# 135    238.000000
# 136     24.000000
# 137    112.000000
# 138    237.000000
# 139    224.000000
# 140     27.000000
# 141    238.000000
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=1)

# %%
x_train
# Out:
#         2    3
# 28   81.0  5.0
# 51   77.0  6.0
# 109  76.0  8.0
# 66   83.0  7.0
# 17   57.0  5.0
# 119  97.0  8.0
# 126  93.0  9.0
# 132  73.0  9.0
# 73   81.0  7.0
# 18   68.0  5.0
# 48   65.0  6.0
# 4    56.0  5.0
# 45   79.0  6.0
# 75   80.0  7.0
# 39   90.0  6.0
# 36   79.0  6.0
# 118  88.0  8.0
# 141  68.0  9.0
# 108  79.0  8.0
# 12   66.0  5.0
# 148  70.0  9.0
# 84   86.0  7.0
# 123  91.0  9.0
# 136  71.0  9.0
# 11   69.0  5.0
# 114  75.0  8.0
# 2    74.0  5.0
# 105  80.0  8.0
# 6    65.0  5.0
# 0    67.0  5.0
# ..    ...  ...
# 13   68.0  5.0
# 88   88.0  7.0
# 8    61.0  5.0
# 81   74.0  7.0
# 60   83.0  6.0
# 128  84.0  9.0
# 1    72.0  5.0
# 57   73.0  6.0
# 22   61.0  5.0
# 61   84.0  7.0
# 63   81.0  7.0
# 7    59.0  5.0
# 86   82.0  7.0
# 96   85.0  8.0
# 68   92.0  7.0
# 50   76.0  6.0
# 139  67.0  9.0
# 101  92.0  8.0
# 20   59.0  5.0
# 25   58.0  5.0
# 134  76.0  9.0
# 71   82.0  7.0
# 129  80.0  9.0
# 144  71.0  9.0
# 79   87.0  7.0
# 133  81.0  9.0
# ...

# %%
y_train
# Out:
# 28     252.000000
# 51     150.000000
# 109    115.000000
# 66     314.000000
# 17      78.000000
# 119    203.000000
# 126    189.000000
# 132    259.000000
# 73     175.000000
# 18     322.000000
# 48      37.000000
# 4      185.931507
# 45     322.000000
# 75      48.000000
# 39     291.000000
# 36     264.000000
# 118    153.000000
# 141    238.000000
# 108     51.000000
# 12     290.000000
# 148    193.000000
# 84     294.000000
# 123    167.000000
# 136     24.000000
# 11     256.000000
# 114    255.000000
# 2      149.000000
# 105    157.000000
# 6      299.000000
# 0      190.000000
#           ...
# 13     274.000000
# 88     213.000000
# 8       19.000000
# 81       7.000000
# 60     138.000000
# 128     92.000000
# 1      118.000000
# 57      47.000000
# 22      25.000000
# 61     269.000000
# 63     236.000000
# 7       99.000000
# 86      81.000000
# 96     185.931507
# 68     267.000000
# 50     137.000000
# 139    224.000000
# 101    222.000000
# 20       8.000000
# ...

# %%
x_test
# Out:
#         2    3
# 59   77.0  6.0
# 33   67.0  6.0
# 69   92.0  7.0
# 127  87.0  9.0
# 31   78.0  6.0
# 107  77.0  8.0
# 97   87.0  8.0
# 14   58.0  5.0
# 53   76.0  6.0
# 44   80.0  6.0
# 147  63.0  9.0
# 138  78.0  9.0
# 78   84.0  7.0
# 102  86.0  8.0
# 5    66.0  5.0
# 85   85.0  7.0
# 16   66.0  5.0
# 100  90.0  8.0
# 89   86.0  7.0
# 95   86.0  8.0
# 91   81.0  7.0
# 124  92.0  9.0
# 92   81.0  8.0
# 99   90.0  8.0
# 93   81.0  8.0
# 40   87.0  6.0
# 29   79.0  5.0
# 42   92.0  6.0
# 54   76.0  6.0
# 122  94.0  8.0
# 35   85.0  6.0
# 19   62.0  5.0
# 113  72.0  8.0
# 103  86.0  8.0
# 77   82.0  7.0
# 145  81.0  9.0
# 58   80.0  6.0
# 121  96.0  8.0
# 56   78.0  6.0

# %%
y_test
# Out:
# 59      31.000000
# 33     242.000000
# 69     272.000000
# 127     95.000000
# 31     286.000000
# 107     71.000000
# 97     185.931507
# 14      65.000000
# 53      91.000000
# 44     332.000000
# 147     20.000000
# 138    237.000000
# 78     285.000000
# 102    137.000000
# 5      185.931507
# 85     223.000000
# 16     307.000000
# 100    207.000000
# 89     275.000000
# 95     185.931507
# 91     254.000000
# 124    197.000000
# 92      83.000000
# 99     229.000000
# 93      24.000000
# 40     323.000000
# 29     223.000000
# 42     250.000000
# 54     250.000000
# 122    188.000000
# 35     220.000000
# 19      44.000000
# 113     36.000000
# 103    192.000000
# 77     274.000000
# 145    139.000000
# 58      98.000000
# 121    237.000000
# 56     127.000000
# Name: 0, dtype: float64

# %%
features=x_train.iloc[:,:].values #feature engineering
features
# Out:
# array([[81.,  5.],
#        [77.,  6.],
#        [76.,  8.],
#        [83.,  7.],
#        [57.,  5.],
#        [97.,  8.],
#        [93.,  9.],
#        [73.,  9.],
#        [81.,  7.],
#        [68.,  5.],
#        [65.,  6.],
#        [56.,  5.],
#        [79.,  6.],
#        [80.,  7.],
#        [90.,  6.],
#        [79.,  6.],
#        [88.,  8.],
#        [68.,  9.],
#        [79.,  8.],
#        [66.,  5.],
#        [70.,  9.],
#        [86.,  7.],
#        [91.,  9.],
#        [71.,  9.],
#        [69.,  5.],
#        [75.,  8.],
#        [74.,  5.],
#        [80.,  8.],
#        [65.,  5.],
#        [67.,  5.],
#        [78.,  8.],
#        [83.,  7.],
#        [75.,  6.],
#        [82.,  8.],
#        [77.,  9.],
#        [77.,  6.],
#        [85.,  7.],
#        [91.,  7.],
#        [86.,  8.],
#        [82.,  8.],
#        [76.,  9.],
#        [83.,  7.],
#        [74.,  5.],
#        [84.,  6.],
#        [74.,  6.],
#        [93.,  9.],
#        [87.,  6.],
# ...

# %%
labels=y_train.iloc[:].values

# %%
labels
# Out:
# array([252.        , 150.        , 115.        , 314.        ,
#         78.        , 203.        , 189.        , 259.        ,
#        175.        , 322.        ,  37.        , 185.93150685,
#        322.        ,  48.        , 291.        , 264.        ,
#        153.        , 238.        ,  51.        , 290.        ,
#        193.        , 294.        , 167.        ,  24.        ,
#        256.        , 255.        , 149.        , 157.        ,
#        299.        , 190.        , 190.        , 175.        ,
#        135.        , 273.        , 238.        , 191.        ,
#        248.        , 291.        , 215.        ,  77.        ,
#        131.        , 253.        , 185.93150685, 186.        ,
#        287.        , 183.        , 273.        , 295.        ,
#        259.        , 223.        ,  13.        ,  92.        ,
#        276.        , 194.        , 230.        , 255.        ,
#        225.        , 238.        ,  82.        , 201.        ,
# ...

# %%
X=features
y=labels

# %%
from sklearn import  linear_model as lm
model=lm.LinearRegression()
results=model.fit(X,y)

# %%
prediction=model.predict(X)
accuracy=model.score(X,y)
print("Accuracy is",accuracy)
# Out:
# Accuracy is 0.07251688906996856

# %%
plt.scatter(y,prediction)
