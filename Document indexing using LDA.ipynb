# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Hiba'

# %%
os.chdir('C://Users/Hiba/Desktop/New folder/Dim Reduction')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Hiba\\Desktop\\New folder\\Dim Reduction'

# %%
pip --version
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip --version
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more informations on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
# !pip install -U nltk
# Out:
# ...
# Requirement already up-to-date: six in c:\users\hiba\anaconda3\lib\site-packages (from nltk)
# ...
#   Running setup.py bdist_wheel for nltk: started
#   Running setup.py bdist_wheel for nltk: finished with status 'done'
#   Stored in directory: C:\Users\Hiba\AppData\Local\pip\Cache\wheels\97\8a\10\d646015f33c525688e91986c4544c68019b19a473cb33d3b55
# Successfully built nltk
# ...
#   Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
# ...
# You are using pip version 9.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import nltk, collections
from nltk.collocations import *

# %%
frequencies = collections.Counter()
with open('price10.txt') as book:
    read_book = book.read()
words = nltk.word_tokenize(read_book)
 
for w in words:
    frequencies[w] += 1
     
print (frequencies)
# Out:
# Counter({'%': 18643, '.': 2966, '4': 2881, 'Est': 2877, '0.0000': 1794, '1.000000': 452, '1.3740': 276, '5.2689': 274, '-1.4749': 274, '1993': 173, ':': 162, '1989': 160, '1979': 152, '1875': 149, '2010': 149, '1947': 147, '1983': 145, '1898': 145, '1900': 145, '1984': 144, '1969': 144, '1982': 144, '1990': 144, '1973': 143, '1985': 143, '1930': 142, '1916': 142, '1933': 142, '1950': 142, '1986': 142, '1987': 142, '1991': 142, ',': 141, 'the': 141, '1981': 141, '1968': 141, '1971': 141, '1988': 141, '1992': 141, '1920': 141, '1914': 141, '1970': 140, '1899': 140, '1978': 140, '1946': 140, '1915': 140, '1980': 140, '1994': 140, '1951': 140, '1919': 140, '1913': 140, '1995': 139, '1996': 139, '1997': 139, '1998': 139, '1999': 139, '2000': 139, '2001': 139, '2002': 139, '2007': 139, '1977': 139, '1976': 139, '1975': 139, '1974': 139, '1972': 139, '1967': 139, '1966': 139, '1965': 139, '1964': 139, '1963': 139, '1962': 139, '1961': 139, '1960': 139, '1959': 139, '1958': 139, '1957': 139,
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hiba\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
import numpy as np
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
import pandas as pd
url = "http://www.textfiles.com/etext/MODERN/"

df = pd.read_csv(url, names=['Text','Size','Description'])
df.head(5)
# Out:
#                                                 Text Size Description
# 0                                             <HTML>  NaN         NaN
# 1         <TITLE>ETEXT.TEXTFILES.COM: MODERN</TITLE>  NaN         NaN
# 2  <BODY BGCOLOR="#000000" TEXT="#DDDDDD" LINK="#...  NaN         NaN
# 3                                                <P>  NaN         NaN
# 4                                           <CENTER>  NaN         NaN
