# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Hiba\\Desktop\\data set\\ml'

# %%
os.chdir('C:/Users/Hiba/Desktop/data set/ml')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Hiba\\Desktop\\data set\\ml'

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing 
import matplotlib.pyplot as plt
# %matplotlib inline
data1=pd.read_csv("airquality.csv")
data1
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 0     41.0    190.0   7.4    67      5    1
# 1     36.0    118.0   8.0    72      5    2
# 2     12.0    149.0  12.6    74      5    3
# 3     18.0    313.0  11.5    62      5    4
# 4      NaN      NaN  14.3    56      5    5
# 5     28.0      NaN  14.9    66      5    6
# 6     23.0    299.0   8.6    65      5    7
# 7     19.0     99.0  13.8    59      5    8
# 8      8.0     19.0  20.1    61      5    9
# 9      NaN    194.0   8.6    69      5   10
# 10     7.0      NaN   6.9    74      5   11
# 11    16.0    256.0   9.7    69      5   12
# 12    11.0    290.0   9.2    66      5   13
# 13    14.0    274.0  10.9    68      5   14
# 14    18.0     65.0  13.2    58      5   15
# 15    14.0    334.0  11.5    64      5   16
# 16    34.0    307.0  12.0    66      5   17
# 17     6.0     78.0  18.4    57      5   18
# 18    30.0    322.0  11.5    68      5   19
# 19    11.0     44.0   9.7    62      5   20
# ...

# %%
df1.corr()
# Out:
#             Ozone   Solar.R      Wind      Temp     Month       Day
# Ozone    1.000000  0.302970 -0.530936  0.608742  0.149081  0.004106
# Solar.R  0.302970  1.000000 -0.055245  0.262569 -0.072904 -0.154340
# Wind    -0.530936 -0.055245  1.000000 -0.457988 -0.178293  0.018440
# Temp     0.608742  0.262569 -0.457988  1.000000  0.420947 -0.109867
# Month    0.149081 -0.072904 -0.178293  0.420947  1.000000 -0.036411
# Day      0.004106 -0.154340  0.018440 -0.109867 -0.036411  1.000000

# %%
#Get a count of missing values in a dataset
data1.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# Ozone      37
# Solar.R     7
# Wind        0
# Temp        0
# Month       0
# Day         0
# dtype: int64

# %%
f=data1.iloc[:,:].values
f
# Out:
# array([[ 41. , 190. ,   7.4,  67. ,   5. ,   1. ],
#        [ 36. , 118. ,   8. ,  72. ,   5. ,   2. ],
#        [ 12. , 149. ,  12.6,  74. ,   5. ,   3. ],
#        [ 18. , 313. ,  11.5,  62. ,   5. ,   4. ],
#        [  nan,   nan,  14.3,  56. ,   5. ,   5. ],
#        [ 28. ,   nan,  14.9,  66. ,   5. ,   6. ],
#        [ 23. , 299. ,   8.6,  65. ,   5. ,   7. ],
#        [ 19. ,  99. ,  13.8,  59. ,   5. ,   8. ],
#        [  8. ,  19. ,  20.1,  61. ,   5. ,   9. ],
#        [  nan, 194. ,   8.6,  69. ,   5. ,  10. ],
#        [  7. ,   nan,   6.9,  74. ,   5. ,  11. ],
#        [ 16. , 256. ,   9.7,  69. ,   5. ,  12. ],
#        [ 11. , 290. ,   9.2,  66. ,   5. ,  13. ],
#        [ 14. , 274. ,  10.9,  68. ,   5. ,  14. ],
#        [ 18. ,  65. ,  13.2,  58. ,   5. ,  15. ],
#        [ 14. , 334. ,  11.5,  64. ,   5. ,  16. ],
#        [ 34. , 307. ,  12. ,  66. ,   5. ,  17. ],
#        [  6. ,  78. ,  18.4,  57. ,   5. ,  18. ],
# ...

# %%
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values='NaN',strategy='mean',axis=0) 
#imputer doesnt work on categorical data but we can recode the categorical data

# %%
imputer.fit(f[:,[0,1]])
f[:,[0,1]]=imputer.fit_transform(f[:,[0,1]])

# %%
df1=pd.DataFrame(f,columns=['Ozone','Solar.R','Wind','Temp','Month','Day'])

# %%
df1.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Temp       0
# Month      0
# Day        0
# dtype: int64

# %%
df1
# Out:
#          Ozone     Solar.R  Wind  Temp  Month   Day
# 0     41.00000  190.000000   7.4  67.0    5.0   1.0
# 1     36.00000  118.000000   8.0  72.0    5.0   2.0
# 2     12.00000  149.000000  12.6  74.0    5.0   3.0
# 3     18.00000  313.000000  11.5  62.0    5.0   4.0
# 4     42.12931  185.931507  14.3  56.0    5.0   5.0
# 5     28.00000  185.931507  14.9  66.0    5.0   6.0
# 6     23.00000  299.000000   8.6  65.0    5.0   7.0
# 7     19.00000   99.000000  13.8  59.0    5.0   8.0
# 8      8.00000   19.000000  20.1  61.0    5.0   9.0
# 9     42.12931  194.000000   8.6  69.0    5.0  10.0
# 10     7.00000  185.931507   6.9  74.0    5.0  11.0
# 11    16.00000  256.000000   9.7  69.0    5.0  12.0
# 12    11.00000  290.000000   9.2  66.0    5.0  13.0
# 13    14.00000  274.000000  10.9  68.0    5.0  14.0
# 14    18.00000   65.000000  13.2  58.0    5.0  15.0
# 15    14.00000  334.000000  11.5  64.0    5.0  16.0
# 16    34.00000  307.000000  12.0  66.0    5.0  17.0
# ...

# %%
#Assign ozone values to an object
Ozone=df1['Ozone']
Ozone
# Out:
# 0       41.00000
# 1       36.00000
# 2       12.00000
# 3       18.00000
# 4       42.12931
# 5       28.00000
# 6       23.00000
# 7       19.00000
# 8        8.00000
# 9       42.12931
# 10       7.00000
# 11      16.00000
# 12      11.00000
# 13      14.00000
# 14      18.00000
# 15      14.00000
# 16      34.00000
# 17       6.00000
# 18      30.00000
# 19      11.00000
# 20       1.00000
# 21      11.00000
# 22       4.00000
# 23      32.00000
# 24      42.12931
# 25      42.12931
# 26      42.12931
# 27      23.00000
# 28      45.00000
# 29     115.00000
#          ...
# 123     96.00000
# 124     78.00000
# 125     73.00000
# 126     91.00000
# 127     47.00000
# 128     32.00000
# 129     20.00000
# 130     23.00000
# 131     21.00000
# 132     24.00000
# 133     44.00000
# 134     21.00000
# 135     28.00000
# 136      9.00000
# 137     13.00000
# 138     46.00000
# 139     18.00000
# 140     13.00000
# 141     24.00000
# 142     16.00000
# 143     13.00000
# ...

# %%
wind=df1['Wind']
wind
# Out:
# 0       7.4
# 1       8.0
# 2      12.6
# 3      11.5
# 4      14.3
# 5      14.9
# 6       8.6
# 7      13.8
# 8      20.1
# 9       8.6
# 10      6.9
# 11      9.7
# 12      9.2
# 13     10.9
# 14     13.2
# 15     11.5
# 16     12.0
# 17     18.4
# 18     11.5
# 19      9.7
# 20      9.7
# 21     16.6
# 22      9.7
# 23     12.0
# 24     16.6
# 25     14.9
# 26      8.0
# 27     12.0
# 28     14.9
# 29      5.7
#        ...
# 123     6.9
# 124     5.1
# 125     2.8
# 126     4.6
# 127     7.4
# 128    15.5
# 129    10.9
# 130    10.3
# 131    10.9
# 132     9.7
# 133    14.9
# 134    15.5
# 135     6.3
# 136    10.9
# 137    11.5
# 138     6.9
# 139    13.8
# 140    10.3
# 141    10.3
# 142     8.0
# 143    12.6
# 144     9.2
# 145    10.3
# 146    10.3
# 147    16.6
# 148     6.9
# 149    13.2
# 150    14.3
# 151     8.0
# 152    11.5
# Name: Wind, Length: 153, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(wind,Ozone,'o')
plt.ylabel("Ozone")
plt.xlabel("Wind")
# Out:
# Text(0.5,0,'Wind')

# %%
mean_ozone=df1['Ozone'].mean()
mean_ozone
# Out:
# 42.1293103448276

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(wind,Ozone,'o')
plt.ylabel("Ozone")
plt.xlabel("Wind")
plt.axhline(mean_ozone,color='r',linestyle='-')
plt.show()

# %%
data1.boxplot(column='Ozone',by='Wind')

# %%
df1.shape
# Out:
# (153, 6)

# %%
df1.describe() #view basic statistical data
# Out:
#             Ozone     Solar.R        Wind        Temp       Month         Day
# count  153.000000  153.000000  153.000000  153.000000  153.000000  153.000000
# mean    42.129310  185.931507    9.957516   77.882353    6.993464   15.627451
# std     28.693372   87.960267    3.523001    9.465270    1.416522    8.848790
# min      1.000000    7.000000    1.700000   56.000000    5.000000    1.000000
# 25%     21.000000  120.000000    7.400000   72.000000    6.000000    8.000000
# 50%     42.129310  194.000000    9.700000   79.000000    7.000000   16.000000
# 75%     46.000000  256.000000   11.500000   85.000000    8.000000   23.000000
# max    168.000000  334.000000   20.700000   97.000000    9.000000   31.000000

# %%
df1.cov() #measures strength betwen 2 or more variable i.e greater than 0-positive
#ozone nd wind velocity have negative covariance-one large value is associated with small values of other
# Out:
#               Ozone      Solar.R       Wind        Temp     Month         Day
# Ozone    823.309608   764.657688 -53.670599  165.328550  6.059381    1.042593
# Solar.R  764.657688  7737.008652 -17.119512  218.606345 -9.083724 -120.129056
# Wind     -53.670599   -17.119512  12.411539  -15.272136 -0.889753    0.574858
# Temp     165.328550   218.606345 -15.272136   89.591331  5.643963   -9.202012
# Month      6.059381    -9.083724  -0.889753    5.643963  2.006536   -0.456398
# Day        1.042593  -120.129056   0.574858   -9.202012 -0.456398   78.301084

# %%
df1.corr()  #measures both strength nd direction of relationship bet 2 variable
# Out:
#             Ozone   Solar.R      Wind      Temp     Month       Day
# Ozone    1.000000  0.302970 -0.530936  0.608742  0.149081  0.004106
# Solar.R  0.302970  1.000000 -0.055245  0.262569 -0.072904 -0.154340
# Wind    -0.530936 -0.055245  1.000000 -0.457988 -0.178293  0.018440
# Temp     0.608742  0.262569 -0.457988  1.000000  0.420947 -0.109867
# Month    0.149081 -0.072904 -0.178293  0.420947  1.000000 -0.036411
# Day      0.004106 -0.154340  0.018440 -0.109867 -0.036411  1.000000

# %%
df1.head()
#Among first five data values-14.3 is d greatest wind velocity fr which ozone concentration found is 42.12
#least concentration of ozone is found at d rate of 12.6 wind velocity
#8 m/s-36 conc
#14.3-42.12 is conc
# Out:
#       Ozone     Solar.R  Wind  Temp  Month  Day
# 0  41.00000  190.000000   7.4  67.0    5.0  1.0
# 1  36.00000  118.000000   8.0  72.0    5.0  2.0
# 2  12.00000  149.000000  12.6  74.0    5.0  3.0
# 3  18.00000  313.000000  11.5  62.0    5.0  4.0
# 4  42.12931  185.931507  14.3  56.0    5.0  5.0

# %%
df1.tail() #but in last 5 data value- Max velo-least conc
#ozone concentation is highest fr 13.2m/s wind vel
#8 m/s-18dobson units is conc
#14.3 m/s-14DU is conc
# Out:
#         Ozone  Solar.R  Wind  Temp  Month   Day
# 148  30.00000    193.0   6.9  70.0    9.0  26.0
# 149  42.12931    145.0  13.2  77.0    9.0  27.0
# 150  14.00000    191.0  14.3  75.0    9.0  28.0
# 151  18.00000    131.0   8.0  76.0    9.0  29.0
# 152  20.00000    223.0  11.5  68.0    9.0   3.0

# %%
df1.columns
# Out:
# Index(['Ozone', 'Solar.R', 'Wind', 'Temp', 'Month', 'Day'], dtype='object')

# %%
df1['Wind']
# Out:
# 0       7.4
# 1       8.0
# 2      12.6
# 3      11.5
# 4      14.3
# 5      14.9
# 6       8.6
# 7      13.8
# 8      20.1
# 9       8.6
# 10      6.9
# 11      9.7
# 12      9.2
# 13     10.9
# 14     13.2
# 15     11.5
# 16     12.0
# 17     18.4
# 18     11.5
# 19      9.7
# 20      9.7
# 21     16.6
# 22      9.7
# 23     12.0
# 24     16.6
# 25     14.9
# 26      8.0
# 27     12.0
# 28     14.9
# 29      5.7
#        ...
# 123     6.9
# 124     5.1
# 125     2.8
# 126     4.6
# 127     7.4
# 128    15.5
# 129    10.9
# 130    10.3
# 131    10.9
# 132     9.7
# 133    14.9
# 134    15.5
# 135     6.3
# 136    10.9
# 137    11.5
# 138     6.9
# 139    13.8
# 140    10.3
# 141    10.3
# 142     8.0
# 143    12.6
# 144     9.2
# 145    10.3
# 146    10.3
# 147    16.6
# 148     6.9
# 149    13.2
# 150    14.3
# 151     8.0
# 152    11.5
# Name: Wind, Length: 153, dtype: float64

# %%
mean_ozone=df1['Ozone'].mean()
mean_ozone
# Out:
# 42.1293103448276

# %%
df1.pivot_table(df1,index=['Wind']) #aggregating data for wind velocity-quicker nd more flexible
# Out:
#             Day     Month       Ozone     Solar.R       Temp
# Wind
# 1.7   22.000000  6.000000   42.129310   59.000000  76.000000
# 2.3   29.000000  8.000000  118.000000  225.000000  94.000000
# 2.8    3.000000  9.000000   73.000000  183.000000  93.000000
# 3.4   25.000000  8.000000  168.000000  238.000000  81.000000
# 4.0    7.000000  8.000000  122.000000  255.000000  89.000000
# 4.1    1.000000  7.000000  135.000000  269.000000  84.000000
# 4.6    9.500000  7.500000   65.782328  160.232877  84.750000
# 5.1    9.333333  7.666667   78.000000  220.000000  89.000000
# 5.7   22.000000  6.666667   84.709770  216.000000  86.333333
# 6.3   20.250000  7.375000   62.282328  208.250000  84.375000
# 6.9   11.555556  7.555556   44.681034  176.873668  80.222222
# 7.4   16.000000  7.100000   48.000000  185.793151  81.900000
# 8.0   21.090909  6.818182   50.228840  166.266501  78.727273
# 8.6   11.750000  6.375000   41.705819  216.875000  79.875000
# ...

# %%
 df1.pivot_table(df1,index=['Ozone']) #pivot is ozone conc
# Out:
#              Day     Month     Solar.R       Temp       Wind
# Ozone
# 1.0    21.000000  5.000000    8.000000  59.000000   9.700000
# 4.0    23.000000  5.000000   25.000000  61.000000   9.700000
# 6.0    18.000000  5.000000   78.000000  57.000000  18.400000
# 7.0    16.666667  7.000000   94.310502  74.333333  10.500000
# 8.0     9.000000  5.000000   19.000000  61.000000  20.100000
# 9.0    12.666667  8.333333   28.000000  74.666667  13.000000
# 10.0   12.000000  7.000000  264.000000  73.000000  14.300000
# 11.0   18.333333  5.000000  218.000000  67.000000  11.833333
# 12.0   11.000000  5.500000  134.500000  73.500000  12.050000
# 13.0   18.500000  8.250000  128.500000  71.750000  11.175000
# 14.0   20.750000  7.000000  204.750000  67.500000  13.325000
# 16.0   14.000000  7.250000  135.250000  76.750000   8.000000
# 18.0   16.250000  7.000000  183.250000  65.750000  11.625000
# 19.0    8.000000  5.000000   99.000000  59.000000  13.800000
# ...

# %%
df1['Wind'].value_counts() #returns counts for wind velocity
# Out:
# 11.5    15
# 8.0     11
# 10.3    11
# 9.7     11
# 7.4     10
# 6.9      9
# 6.3      8
# 10.9     8
# 8.6      8
# 14.9     8
# 9.2      8
# 14.3     6
# 13.8     5
# 12.0     4
# 4.6      4
# 5.1      3
# 12.6     3
# 16.6     3
# 15.5     3
# 5.7      3
# 13.2     2
# 4.0      1
# 16.1     1
# 18.4     1
# 4.1      1
# 2.3      1
# 20.1     1
# 20.7     1
# 1.7      1
# 3.4      1
# 2.8      1
# Name: Wind, dtype: int64

# %%
df1['Ozone'].value_counts() #returns counts for ozon con
# Out:
# 42.12931     37
# 23.00000      6
# 18.00000      4
# 16.00000      4
# 14.00000      4
# 13.00000      4
# 20.00000      4
# 21.00000      4
# 9.00000       3
# 28.00000      3
# 7.00000       3
# 11.00000      3
# 32.00000      3
# 44.00000      3
# 39.00000      2
# 64.00000      2
# 30.00000      2
# 37.00000      2
# 45.00000      2
# 35.00000      2
# 12.00000      2
# 36.00000      2
# 97.00000      2
# 85.00000      2
# 73.00000      2
# 24.00000      2
# 78.00000      2
# 59.00000      2
# 168.00000     1
# 65.00000      1
#              ..
# 76.00000      1
# 118.00000     1
# 8.00000       1
# 19.00000      1
# 84.00000      1
# 96.00000      1
# 91.00000      1
# 47.00000      1
# 115.00000     1
# 29.00000      1
# 108.00000     1
# 71.00000      1
# 80.00000      1
# 63.00000      1
# 79.00000      1
# 61.00000      1
# 82.00000      1
# 48.00000      1
# 27.00000      1
# 10.00000      1
# 46.00000      1
# 50.00000      1
# 77.00000      1
# 40.00000      1
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df1['Wind'].hist(bins=10) #histogram fr wind vel

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df1['Ozone'].hist(bins=10)

# %%
import seaborn as sns
sns.pairplot(df1,kind="reg",markers=["D"])
# Out:
# C:\Users\Hiba\Anaconda3\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(data1['Wind'])
# Out:
# C:\Users\Hiba\Anaconda3\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df1['Ozone'])
# Out:
# C:\Users\Hiba\Anaconda3\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
corr=df1.corr() #black color=-ve correlation
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)

# %%
plt.plot(wind,Ozone,'o')
plt.ylabel("Ozone")
plt.xlabel("wind")
plt.axhline(mean_ozone,color='r',linestyle='-')
sns.regplot(x='Wind',y='Ozone',data=data1)
plt.show()
#plot data nd linear regression model fit
# Out:
# C:\Users\Hiba\Anaconda3\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
import statsmodels.api as sm #statiscal data exploration-using ordinary least square(sensitive to outliers)
model=sm.OLS(Ozone,wind).fit()
model.summary()
#total of square of erors must b minimised nd fit onto straight line
#null hypothesis,alternate hypo
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Ozone   R-squared:                       0.464
# Model:                            OLS   Adj. R-squared:                  0.460
# Method:                 Least Squares   F-statistic:                     131.5
# Date:                Mon, 27 May 2019   Prob (F-statistic):           2.49e-22
# Time:                        17:10:01   Log-Likelihood:                -770.73
# No. Observations:                 153   AIC:                             1543.
# Df Residuals:                     152   BIC:                             1546.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Wind           3.2847      0.286     11.469      0.000       2.719       3.851
# ...

# %%
#OBSERVation- As wind velocity increases by 1 m/s,ozone conc increases by 3.2847 i.e model of summary

# %%
X=df1['Wind'] #splitting data
y=df1['Ozone']

# %%
X
# Out:
# 0       7.4
# 1       8.0
# 2      12.6
# 3      11.5
# 4      14.3
# 5      14.9
# 6       8.6
# 7      13.8
# 8      20.1
# 9       8.6
# 10      6.9
# 11      9.7
# 12      9.2
# 13     10.9
# 14     13.2
# 15     11.5
# 16     12.0
# 17     18.4
# 18     11.5
# 19      9.7
# 20      9.7
# 21     16.6
# 22      9.7
# 23     12.0
# 24     16.6
# 25     14.9
# 26      8.0
# 27     12.0
# 28     14.9
# 29      5.7
#        ...
# 123     6.9
# 124     5.1
# 125     2.8
# 126     4.6
# 127     7.4
# 128    15.5
# 129    10.9
# 130    10.3
# 131    10.9
# 132     9.7
# 133    14.9
# 134    15.5
# 135     6.3
# 136    10.9
# 137    11.5
# 138     6.9
# 139    13.8
# 140    10.3
# 141    10.3
# 142     8.0
# 143    12.6
# 144     9.2
# 145    10.3
# 146    10.3
# 147    16.6
# 148     6.9
# 149    13.2
# 150    14.3
# 151     8.0
# 152    11.5
# Name: Wind, Length: 153, dtype: float64

# %%
y
# Out:
# 0       41.00000
# 1       36.00000
# 2       12.00000
# 3       18.00000
# 4       42.12931
# 5       28.00000
# 6       23.00000
# 7       19.00000
# 8        8.00000
# 9       42.12931
# 10       7.00000
# 11      16.00000
# 12      11.00000
# 13      14.00000
# 14      18.00000
# 15      14.00000
# 16      34.00000
# 17       6.00000
# 18      30.00000
# 19      11.00000
# 20       1.00000
# 21      11.00000
# 22       4.00000
# 23      32.00000
# 24      42.12931
# 25      42.12931
# 26      42.12931
# 27      23.00000
# 28      45.00000
# 29     115.00000
#          ...
# 123     96.00000
# 124     78.00000
# 125     73.00000
# 126     91.00000
# 127     47.00000
# 128     32.00000
# 129     20.00000
# 130     23.00000
# 131     21.00000
# 132     24.00000
# 133     44.00000
# 134     21.00000
# 135     28.00000
# 136      9.00000
# 137     13.00000
# 138     46.00000
# 139     18.00000
# 140     13.00000
# 141     24.00000
# 142     16.00000
# 143     13.00000
# ...

# %%
x=df1.loc[:,['Wind']]
x
# Out:
#      Wind
# 0     7.4
# 1     8.0
# 2    12.6
# 3    11.5
# 4    14.3
# 5    14.9
# 6     8.6
# 7    13.8
# 8    20.1
# 9     8.6
# 10    6.9
# 11    9.7
# 12    9.2
# 13   10.9
# 14   13.2
# 15   11.5
# 16   12.0
# 17   18.4
# 18   11.5
# 19    9.7
# 20    9.7
# 21   16.6
# 22    9.7
# 23   12.0
# 24   16.6
# 25   14.9
# 26    8.0
# 27   12.0
# 28   14.9
# 29    5.7
# ..    ...
# 123   6.9
# 124   5.1
# 125   2.8
# 126   4.6
# 127   7.4
# 128  15.5
# 129  10.9
# 130  10.3
# 131  10.9
# 132   9.7
# 133  14.9
# 134  15.5
# 135   6.3
# 136  10.9
# 137  11.5
# 138   6.9
# 139  13.8
# 140  10.3
# 141  10.3
# 142   8.0
# 143  12.6
# 144   9.2
# 145  10.3
# 146  10.3
# 147  16.6
# 148   6.9
# 149  13.2
# 150  14.3
# 151   8.0
# 152  11.5
#
# [153 rows x 1 columns]

# %%
x.describe()
# Out:
#              Wind
# count  153.000000
# mean     9.957516
# std      3.523001
# min      1.700000
# 25%      7.400000
# 50%      9.700000
# 75%     11.500000
# max     20.700000

# %%
y=y.values.reshape((-1,1)) #gives new shape to array without changing data
y
# Out:
# array([[ 41.        ],
#        [ 36.        ],
#        [ 12.        ],
#        [ 18.        ],
#        [ 42.12931034],
#        [ 28.        ],
#        [ 23.        ],
#        [ 19.        ],
#        [  8.        ],
#        [ 42.12931034],
#        [  7.        ],
#        [ 16.        ],
#        [ 11.        ],
#        [ 14.        ],
#        [ 18.        ],
#        [ 14.        ],
#        [ 34.        ],
#        [  6.        ],
#        [ 30.        ],
#        [ 11.        ],
#        [  1.        ],
#        [ 11.        ],
#        [  4.        ],
#        [ 32.        ],
#        [ 42.12931034],
#        [ 42.12931034],
#        [ 42.12931034],
#        [ 23.        ],
#        [ 45.        ],
#        [115.        ],
#        [ 37.        ],
#        [ 42.12931034],
#        [ 42.12931034],
#        [ 42.12931034],
#        [ 42.12931034],
#        [ 42.12931034],
#        [ 42.12931034],
#        [ 29.        ],
#        [ 42.12931034],
#        [ 71.        ],
# ...

# %%
minmax=preprocessing.MinMaxScaler(feature_range=(0,1))
N=minmax.fit(y).transform(y)
N
# Out:
# array([[0.23952096],
#        [0.20958084],
#        [0.06586826],
#        [0.10179641],
#        [0.2462833 ],
#        [0.16167665],
#        [0.13173653],
#        [0.10778443],
#        [0.04191617],
#        [0.2462833 ],
#        [0.03592814],
#        [0.08982036],
#        [0.05988024],
#        [0.07784431],
#        [0.10179641],
#        [0.07784431],
#        [0.19760479],
#        [0.02994012],
#        [0.17365269],
#        [0.05988024],
#        [0.        ],
#        [0.05988024],
#        [0.01796407],
#        [0.18562874],
#        [0.2462833 ],
#        [0.2462833 ],
#        [0.2462833 ],
#        [0.13173653],
#        [0.26347305],
#        [0.68263473],
#        [0.21556886],
#        [0.2462833 ],
#        [0.2462833 ],
#        [0.2462833 ],
#        [0.2462833 ],
#        [0.2462833 ],
#        [0.2462833 ],
#        [0.16766467],
#        [0.2462833 ],
#        [0.41916168],
#        [0.22754491],
#        [0.2462833 ],
#        [0.2462833 ],
# ...

# %%
#scalar=preprocessing.StandardScaler().fit(y)
#scalar

# %%
#Split data into training set and test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,N,test_size=0.25,random_state=1) #split the data into training and test set

# %%
x_train
# Out:
#      Wind
# 28   14.9
# 51    6.3
# 109   7.4
# 66   10.9
# 17   18.4
# 119   9.7
# 126   4.6
# 132   9.7
# 73   14.9
# 18   11.5
# 48    9.2
# 4    14.3
# 45   11.5
# 75   14.3
# 39   13.8
# 36   14.3
# 118   5.7
# 141  10.3
# 108   6.3
# 12    9.2
# 148   6.9
# 84    8.6
# 123   6.9
# 136  10.9
# 11    9.7
# 114  12.6
# 2    12.6
# 105   9.7
# 6     8.6
# 0     7.4
# ..    ...
# 13   10.9
# 88    7.4
# 8    20.1
# 81    6.9
# 60    8.0
# 128  15.5
# 1     8.0
# 57   10.3
# 22    9.7
# 61    4.1
# 63    9.2
# 7    13.8
# 86    8.6
# 96    7.4
# 68    6.3
# 50   10.3
# 139  13.8
# 101   8.6
# 20    9.7
# 25   14.9
# 134  15.5
# 71    8.6
# 129  10.9
# 144   9.2
# 79    5.1
# 133  14.9
# 137  11.5
# 72   14.3
# 140  10.3
# 37    9.7
#
# [114 rows x 1 columns]

# %%
y_train
# Out:
# array([[0.26347305],
#        [0.2462833 ],
#        [0.13173653],
#        [0.23353293],
#        [0.02994012],
#        [0.4491018 ],
#        [0.53892216],
#        [0.13772455],
#        [0.15568862],
#        [0.17365269],
#        [0.11377246],
#        [0.2462833 ],
#        [0.2462833 ],
#        [0.03592814],
#        [0.41916168],
#        [0.2462833 ],
#        [0.2462833 ],
#        [0.13772455],
#        [0.34730539],
#        [0.05988024],
#        [0.17365269],
#        [0.47305389],
#        [0.56886228],
#        [0.04790419],
#        [0.08982036],
#        [0.2462833 ],
#        [0.06586826],
#        [0.38323353],
#        [0.13173653],
#        [0.23952096],
#        [0.25748503],
#        [0.37724551],
#        [0.2462833 ],
#        [0.16167665],
#        [0.16167665],
#        [0.11976048],
#        [0.28742515],
#        [0.2462833 ],
#        [0.43113772],
#        [0.08982036],
#        [0.10179641],
#        [0.37724551],
#        [0.03592814],
# ...

# %%
x_test
# Out:
#      Wind
# 59   14.9
# 33   16.1
# 69    5.7
# 127   7.4
# 31    8.6
# 107  10.3
# 97    4.6
# 14   13.2
# 53    4.6
# 44   13.8
# 147  16.6
# 138   6.9
# 78    6.3
# 102  11.5
# 5    14.9
# 85    8.0
# 16   12.0
# 100   8.0
# 89    7.4
# 95    6.9
# 91    9.2
# 124   5.1
# 92    6.9
# 99   10.3
# 93   13.8
# 40   11.5
# 29    5.7
# 42    9.2
# 54    6.3
# 122   6.3
# 35    8.6
# 19    9.7
# 113  14.3
# 103  11.5
# 77   10.3
# 145  10.3
# 58   11.5
# 121   6.3
# 56    8.0

# %%
y_test
# Out:
# array([[0.2462833 ],
#        [0.2462833 ],
#        [0.5748503 ],
#        [0.2754491 ],
#        [0.2462833 ],
#        [0.1257485 ],
#        [0.38922156],
#        [0.10179641],
#        [0.2462833 ],
#        [0.2462833 ],
#        [0.07784431],
#        [0.26946108],
#        [0.35928144],
#        [0.2462833 ],
#        [0.16167665],
#        [0.64071856],
#        [0.19760479],
#        [0.65269461],
#        [0.29341317],
#        [0.46107784],
#        [0.34730539],
#        [0.46107784],
#        [0.22754491],
#        [0.52694611],
#        [0.04790419],
#        [0.22754491],
#        [0.68263473],
#        [0.2462833 ],
#        [0.2462833 ],
#        [0.50299401],
#        [0.2462833 ],
#        [0.05988024],
#        [0.04790419],
#        [0.25748503],
#        [0.20359281],
#        [0.20958084],
#        [0.2462833 ],
#        [0.49700599],
#        [0.2462833 ]])

# %%
x_train=x_train.values.reshape((-1,1)) #gives new shape to array without changing data
x_train
# Out:
# array([[14.9],
#        [ 6.3],
#        [ 7.4],
#        [10.9],
#        [18.4],
#        [ 9.7],
#        [ 4.6],
#        [ 9.7],
#        [14.9],
#        [11.5],
#        [ 9.2],
#        [14.3],
#        [11.5],
#        [14.3],
#        [13.8],
#        [14.3],
#        [ 5.7],
#        [10.3],
#        [ 6.3],
#        [ 9.2],
#        [ 6.9],
#        [ 8.6],
#        [ 6.9],
#        [10.9],
#        [ 9.7],
#        [12.6],
#        [12.6],
#        [ 9.7],
#        [ 8.6],
#        [ 7.4],
#        [10.3],
#        [ 4.6],
#        [ 8. ],
#        [11.5],
#        [ 6.3],
#        [14.9],
#        [ 9.2],
#        [14.9],
#        [ 8. ],
#        [ 7.4],
#        [ 8. ],
#        [ 7.4],
#        [ 6.9],
#        [ 9.2],
#        [ 9.7],
#        [ 2.8],
#        [ 6.9],
#        [11.5],
#        [15.5],
#        [11.5],
#        [12. ],
#        [12. ],
#        [ 5.1],
#        [ 8.6],
#        [10.9],
#        [ 4. ],
#        [ 2.3],
#        [12.6],
# ...

# %%
from sklearn import  linear_model as lm #relationship bet independent nd dependent var
model=lm.LinearRegression()
results=model.fit(x_train,y_train)
#used fr predicting a response using a single feature

# %%
accuracy=model.score(x_train,y_train)
print("Accuracy is",accuracy)
# Out:
# Accuracy is 0.25686497573664135

# %%
#print coef
print('intercept',model.intercept_)
print('slope',model.coef_)
#observation- the slope value is -ve predicted so wind vel increases whem ozone conc decreases
# Out:
# intercept [0.47265019]
# slope [[-0.02414434]]

# %%
#rotate
x_test=x_test.values.reshape((-1,1))

# %%
x_test
# Out:
# array([[14.9],
#        [16.1],
#        [ 5.7],
#        [ 7.4],
#        [ 8.6],
#        [10.3],
#        [ 4.6],
#        [13.2],
#        [ 4.6],
#        [13.8],
#        [16.6],
#        [ 6.9],
#        [ 6.3],
#        [11.5],
#        [14.9],
#        [ 8. ],
#        [12. ],
#        [ 8. ],
#        [ 7.4],
#        [ 6.9],
#        [ 9.2],
#        [ 5.1],
#        [ 6.9],
#        [10.3],
#        [13.8],
#        [11.5],
#        [ 5.7],
#        [ 9.2],
#        [ 6.3],
#        [ 6.3],
#        [ 8.6],
#        [ 9.7],
#        [14.3],
#        [11.5],
#        [10.3],
#        [10.3],
#        [11.5],
#        [ 6.3],
#        [ 8. ]])

# %%
predictions=model.predict(x_test)
print('predicted Ozone',predictions,sep='\n')
# Out:
# predicted Ozone
# [[0.11289955]
#  [0.08392635]
#  [0.33502746]
#  [0.29398209]
#  [0.26500888]
#  [0.22396351]
#  [0.36158623]
#  [0.15394493]
#  [0.36158623]
#  [0.13945832]
#  [0.07185418]
#  [0.30605426]
#  [0.32054086]
#  [0.1949903 ]
#  [0.11289955]
#  [0.27949548]
#  [0.18291813]
#  [0.27949548]
#  [0.29398209]
#  [0.30605426]
#  [0.25052228]
#  [0.34951406]
#  [0.30605426]
#  [0.22396351]
#  [0.13945832]
#  [0.1949903 ]
#  [0.33502746]
#  [0.25052228]
#  [0.32054086]
#  [0.32054086]
#  [0.26500888]
#  [0.23845011]
#  [0.12738615]
#  [0.1949903 ]
#  [0.22396351]
#  [0.22396351]
#  [0.1949903 ]
#  [0.32054086]
#  [0.27949548]]

# %%
print(y_test) #actual values
# Out:
# [[0.2462833 ]
#  [0.2462833 ]
#  [0.5748503 ]
#  [0.2754491 ]
#  [0.2462833 ]
#  [0.1257485 ]
#  [0.38922156]
#  [0.10179641]
#  [0.2462833 ]
#  [0.2462833 ]
#  [0.07784431]
#  [0.26946108]
#  [0.35928144]
#  [0.2462833 ]
#  [0.16167665]
#  [0.64071856]
#  [0.19760479]
#  [0.65269461]
#  [0.29341317]
#  [0.46107784]
#  [0.34730539]
#  [0.46107784]
#  [0.22754491]
#  [0.52694611]
#  [0.04790419]
#  [0.22754491]
#  [0.68263473]
#  [0.2462833 ]
#  [0.2462833 ]
#  [0.50299401]
#  [0.2462833 ]
#  [0.05988024]
#  [0.04790419]
#  [0.25748503]
#  [0.20359281]
#  [0.20958084]
#  [0.2462833 ]
#  [0.49700599]
#  [0.2462833 ]]

# %%
plt.scatter(y_test,predictions)

# %%
y_pred=model.intercept_+model.coef_*x_test
print('predicted responsw:',y_pred,sep='\n')
# Out:
# predicted responsw:
# [[0.11289955]
#  [0.08392635]
#  [0.33502746]
#  [0.29398209]
#  [0.26500888]
#  [0.22396351]
#  [0.36158623]
#  [0.15394493]
#  [0.36158623]
#  [0.13945832]
#  [0.07185418]
#  [0.30605426]
#  [0.32054086]
#  [0.1949903 ]
#  [0.11289955]
#  [0.27949548]
#  [0.18291813]
#  [0.27949548]
#  [0.29398209]
#  [0.30605426]
#  [0.25052228]
#  [0.34951406]
#  [0.30605426]
#  [0.22396351]
#  [0.13945832]
#  [0.1949903 ]
#  [0.33502746]
#  [0.25052228]
#  [0.32054086]
#  [0.32054086]
#  [0.26500888]
#  [0.23845011]
#  [0.12738615]
#  [0.1949903 ]
#  [0.22396351]
#  [0.22396351]
#  [0.1949903 ]
#  [0.32054086]
#  [0.27949548]]

# %%
#Define new data instance
Xnew=[[5]]
#MAKE a predition
ynew=model.predict(Xnew)
ynew=minmax.inverse_transform(ynew) #decompress values to get actual predicted val
#show inputs nd predicted outputs
print("New wind=%s,Predicted Ozone=%s"%(Xnew,ynew))
# Out:
# New wind=[[5]],Predicted Ozone=[[59.77205924]]

# %%
Xnew=[[18]]
ynew=model.predict(Xnew)
print("New wind velocity=%s,Predicted Ozone=%s"%(Xnew,ynew))
# Out:
# New wind velocity=[[18]],Predicted Ozone=[[0.0380521]]

# %%
#Evaluating the model
from sklearn.metrics import mean_squared_error,r2_score
x_train=x_train.reshape(-1,1)
y_train_prediction=model.predict(x_train)

x_test=x_test.reshape(-1,1)
y_test_prediction=model.predict(x_test)

# %%
#model evaluation for training set

import numpy as np
rmse_training=(np.sqrt(mean_squared_error(y_train,y_train_prediction)))
r2_training=r2_score(y_train,y_train_prediction)

print("The model performance for training set")
print("__________________")
print("RMSE is {}".format(rmse_training))
print('R2 score is {}'.format(r2_training))
print("\n")
# Out:
# The model performance for training set
# __________________
# RMSE is 0.14657916900516027
# R2 score is 0.25686497573664135

# %%
#model evaluation for test set
rmse_testing=(np.sqrt(mean_squared_error(y_test,y_test_prediction)))
r2_testing=r2_score(y_test,y_test_prediction)

print("The model performance for testing set")
print("__________________")
print("RMSE is {}".format(rmse_testing))
print('R2 score is {}'.format(r2_testing))
print("\n")
# Out:
# The model performance for testing set
# __________________
# RMSE is 0.14401888417068656
# R2 score is 0.23378185468690704

# %%
#Observation- RMSE score is slightly decfreasing
#R2 score also decreases
#Accuracy-25.6%

# %%
plt.scatter(x,y)
plt.xlabel('wind')
plt.ylabel('Ozone')
# Out:
# Text(0,0.5,'Ozone')

# %%
X=X.reshape(-1,1)
y_predicted=model.predict(X)
# Out:
# C:\Users\Hiba\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   """Entry point for launching an IPython kernel.

# %%
y_predicted
# Out:
# array([[ 0.29398209],
#        [ 0.27949548],
#        [ 0.16843153],
#        [ 0.1949903 ],
#        [ 0.12738615],
#        [ 0.11289955],
#        [ 0.26500888],
#        [ 0.13945832],
#        [-0.01265101],
#        [ 0.26500888],
#        [ 0.30605426],
#        [ 0.23845011],
#        [ 0.25052228],
#        [ 0.2094769 ],
#        [ 0.15394493],
#        [ 0.1949903 ],
#        [ 0.18291813],
#        [ 0.02839437],
#        [ 0.1949903 ],
#        [ 0.23845011],
#        [ 0.23845011],
#        [ 0.07185418],
#        [ 0.23845011],
#        [ 0.18291813],
#        [ 0.07185418],
#        [ 0.11289955],
#        [ 0.27949548],
#        [ 0.18291813],
#        [ 0.11289955],
#        [ 0.33502746],
#        [ 0.29398209],
#        [ 0.26500888],
#        [ 0.23845011],
#        [ 0.08392635],
#        [ 0.25052228],
#        [ 0.26500888],
#        [ 0.12738615],
#        [ 0.23845011],
#        [ 0.30605426],
#        [ 0.13945832],
#        [ 0.1949903 ],
# ...

# %%
plt.plot(X,y_predicted,color='r')
plt.show()

# %% [markdown]
# # MULTIPLE REGRESION

# %%
X=data1[["Wind","Temp"]]
y=df1['Ozone']

model1=sm.OLS(y,X).fit()
predictions=model1.predict(X)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Ozone   R-squared:                       0.822
# Model:                            OLS   Adj. R-squared:                  0.819
# Method:                 Least Squares   F-statistic:                     347.6
# Date:                Mon, 27 May 2019   Prob (F-statistic):           3.08e-57
# Time:                        17:10:06   Log-Likelihood:                -686.58
# No. Observations:                 153   AIC:                             1377.
# Df Residuals:                     151   BIC:                             1383.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Wind          -3.3877      0.418     -8.108      0.000      -4.213      -2.562
# ...

# %%
x=df1.loc[:,['Wind','Temp']]
x
# Out:
#      Wind  Temp
# 0     7.4  67.0
# 1     8.0  72.0
# 2    12.6  74.0
# 3    11.5  62.0
# 4    14.3  56.0
# 5    14.9  66.0
# 6     8.6  65.0
# 7    13.8  59.0
# 8    20.1  61.0
# 9     8.6  69.0
# 10    6.9  74.0
# 11    9.7  69.0
# 12    9.2  66.0
# 13   10.9  68.0
# 14   13.2  58.0
# 15   11.5  64.0
# 16   12.0  66.0
# 17   18.4  57.0
# 18   11.5  68.0
# 19    9.7  62.0
# 20    9.7  59.0
# 21   16.6  73.0
# 22    9.7  61.0
# 23   12.0  61.0
# 24   16.6  57.0
# 25   14.9  58.0
# 26    8.0  57.0
# 27   12.0  67.0
# 28   14.9  81.0
# 29    5.7  79.0
# ..    ...   ...
# 123   6.9  91.0
# 124   5.1  92.0
# 125   2.8  93.0
# 126   4.6  93.0
# 127   7.4  87.0
# 128  15.5  84.0
# 129  10.9  80.0
# 130  10.3  78.0
# 131  10.9  75.0
# 132   9.7  73.0
# 133  14.9  81.0
# 134  15.5  76.0
# 135   6.3  77.0
# 136  10.9  71.0
# 137  11.5  71.0
# 138   6.9  78.0
# 139  13.8  67.0
# 140  10.3  76.0
# 141  10.3  68.0
# 142   8.0  82.0
# 143  12.6  64.0
# 144   9.2  71.0
# 145  10.3  81.0
# ...

# %%
x.describe()
# Out:
#              Wind        Temp
# count  153.000000  153.000000
# mean     9.957516   77.882353
# std      3.523001    9.465270
# min      1.700000   56.000000
# 25%      7.400000   72.000000
# 50%      9.700000   79.000000
# 75%     11.500000   85.000000
# max     20.700000   97.000000

# %%
df1['Wind'].max()
# Out:
# 20.7

# %%
minmax=preprocessing.MinMaxScaler(feature_range=(0,1))
N=minmax.fit(x).transform(x)
N
# Out:
# array([[0.3       , 0.26829268],
#        [0.33157895, 0.3902439 ],
#        [0.57368421, 0.43902439],
#        [0.51578947, 0.14634146],
#        [0.66315789, 0.        ],
#        [0.69473684, 0.24390244],
#        [0.36315789, 0.2195122 ],
#        [0.63684211, 0.07317073],
#        [0.96842105, 0.12195122],
#        [0.36315789, 0.31707317],
#        [0.27368421, 0.43902439],
#        [0.42105263, 0.31707317],
#        [0.39473684, 0.24390244],
#        [0.48421053, 0.29268293],
#        [0.60526316, 0.04878049],
#        [0.51578947, 0.19512195],
#        [0.54210526, 0.24390244],
#        [0.87894737, 0.02439024],
#        [0.51578947, 0.29268293],
#        [0.42105263, 0.14634146],
#        [0.42105263, 0.07317073],
#        [0.78421053, 0.41463415],
#        [0.42105263, 0.12195122],
#        [0.54210526, 0.12195122],
#        [0.78421053, 0.02439024],
#        [0.69473684, 0.04878049],
#        [0.33157895, 0.02439024],
#        [0.54210526, 0.26829268],
# ...

# %%
y=df1.iloc[:,0]
y
# Out:
# 0       41.00000
# 1       36.00000
# 2       12.00000
# 3       18.00000
# 4       42.12931
# 5       28.00000
# 6       23.00000
# 7       19.00000
# 8        8.00000
# 9       42.12931
# 10       7.00000
# 11      16.00000
# 12      11.00000
# 13      14.00000
# 14      18.00000
# 15      14.00000
# 16      34.00000
# 17       6.00000
# 18      30.00000
# 19      11.00000
# 20       1.00000
# 21      11.00000
# 22       4.00000
# 23      32.00000
# 24      42.12931
# 25      42.12931
# 26      42.12931
# 27      23.00000
# 28      45.00000
# 29     115.00000
#          ...
# 123     96.00000
# 124     78.00000
# 125     73.00000
# 126     91.00000
# 127     47.00000
# 128     32.00000
# 129     20.00000
# 130     23.00000
# 131     21.00000
# 132     24.00000
# 133     44.00000
# 134     21.00000
# 135     28.00000
# 136      9.00000
# 137     13.00000
# 138     46.00000
# 139     18.00000
# 140     13.00000
# 141     24.00000
# 142     16.00000
# 143     13.00000
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,N,test_size=0.25,random_state=1)

# %%
x_train
# Out:
#      Wind  Temp
# 28   14.9  81.0
# 51    6.3  77.0
# 109   7.4  76.0
# 66   10.9  83.0
# 17   18.4  57.0
# 119   9.7  97.0
# 126   4.6  93.0
# 132   9.7  73.0
# 73   14.9  81.0
# 18   11.5  68.0
# 48    9.2  65.0
# 4    14.3  56.0
# 45   11.5  79.0
# 75   14.3  80.0
# 39   13.8  90.0
# 36   14.3  79.0
# 118   5.7  88.0
# 141  10.3  68.0
# 108   6.3  79.0
# 12    9.2  66.0
# 148   6.9  70.0
# 84    8.6  86.0
# 123   6.9  91.0
# 136  10.9  71.0
# 11    9.7  69.0
# 114  12.6  75.0
# 2    12.6  74.0
# 105   9.7  80.0
# 6     8.6  65.0
# 0     7.4  67.0
# ..    ...   ...
# 13   10.9  68.0
# 88    7.4  88.0
# 8    20.1  61.0
# 81    6.9  74.0
# 60    8.0  83.0
# 128  15.5  84.0
# 1     8.0  72.0
# 57   10.3  73.0
# 22    9.7  61.0
# 61    4.1  84.0
# 63    9.2  81.0
# 7    13.8  59.0
# 86    8.6  82.0
# 96    7.4  85.0
# 68    6.3  92.0
# 50   10.3  76.0
# 139  13.8  67.0
# 101   8.6  92.0
# 20    9.7  59.0
# 25   14.9  58.0
# 134  15.5  76.0
# 71    8.6  82.0
# 129  10.9  80.0
# ...

# %%
y_train
# Out:
# array([[0.69473684, 0.6097561 ],
#        [0.24210526, 0.51219512],
#        [0.3       , 0.48780488],
#        [0.48421053, 0.65853659],
#        [0.87894737, 0.02439024],
#        [0.42105263, 1.        ],
#        [0.15263158, 0.90243902],
#        [0.42105263, 0.41463415],
#        [0.69473684, 0.6097561 ],
#        [0.51578947, 0.29268293],
#        [0.39473684, 0.2195122 ],
#        [0.66315789, 0.        ],
#        [0.51578947, 0.56097561],
#        [0.66315789, 0.58536585],
#        [0.63684211, 0.82926829],
#        [0.66315789, 0.56097561],
#        [0.21052632, 0.7804878 ],
#        [0.45263158, 0.29268293],
#        [0.24210526, 0.56097561],
#        [0.39473684, 0.24390244],
#        [0.27368421, 0.34146341],
#        [0.36315789, 0.73170732],
#        [0.27368421, 0.85365854],
#        [0.48421053, 0.36585366],
#        [0.42105263, 0.31707317],
#        [0.57368421, 0.46341463],
#        [0.57368421, 0.43902439],
#        [0.42105263, 0.58536585],
# ...

# %%
x_test
# Out:
#      Wind  Temp
# 59   14.9  77.0
# 33   16.1  67.0
# 69    5.7  92.0
# 127   7.4  87.0
# 31    8.6  78.0
# 107  10.3  77.0
# 97    4.6  87.0
# 14   13.2  58.0
# 53    4.6  76.0
# 44   13.8  80.0
# 147  16.6  63.0
# 138   6.9  78.0
# 78    6.3  84.0
# 102  11.5  86.0
# 5    14.9  66.0
# 85    8.0  85.0
# 16   12.0  66.0
# 100   8.0  90.0
# 89    7.4  86.0
# 95    6.9  86.0
# 91    9.2  81.0
# 124   5.1  92.0
# 92    6.9  81.0
# 99   10.3  90.0
# 93   13.8  81.0
# 40   11.5  87.0
# 29    5.7  79.0
# 42    9.2  92.0
# 54    6.3  76.0
# 122   6.3  94.0
# 35    8.6  85.0
# 19    9.7  62.0
# 113  14.3  72.0
# 103  11.5  86.0
# 77   10.3  82.0
# 145  10.3  81.0
# 58   11.5  80.0
# 121   6.3  96.0
# 56    8.0  78.0

# %%
y_test
# Out:
# array([[0.69473684, 0.51219512],
#        [0.75789474, 0.26829268],
#        [0.21052632, 0.87804878],
#        [0.3       , 0.75609756],
#        [0.36315789, 0.53658537],
#        [0.45263158, 0.51219512],
#        [0.15263158, 0.75609756],
#        [0.60526316, 0.04878049],
#        [0.15263158, 0.48780488],
#        [0.63684211, 0.58536585],
#        [0.78421053, 0.17073171],
#        [0.27368421, 0.53658537],
#        [0.24210526, 0.68292683],
#        [0.51578947, 0.73170732],
#        [0.69473684, 0.24390244],
#        [0.33157895, 0.70731707],
#        [0.54210526, 0.24390244],
#        [0.33157895, 0.82926829],
#        [0.3       , 0.73170732],
#        [0.27368421, 0.73170732],
#        [0.39473684, 0.6097561 ],
#        [0.17894737, 0.87804878],
#        [0.27368421, 0.6097561 ],
#        [0.45263158, 0.82926829],
#        [0.63684211, 0.6097561 ],
#        [0.51578947, 0.75609756],
#        [0.21052632, 0.56097561],
#        [0.39473684, 0.87804878],
# ...

# %%
features=x_train.iloc[:,:].values #feature engineering
features
# Out:
# array([[14.9, 81. ],
#        [ 6.3, 77. ],
#        [ 7.4, 76. ],
#        [10.9, 83. ],
#        [18.4, 57. ],
#        [ 9.7, 97. ],
#        [ 4.6, 93. ],
#        [ 9.7, 73. ],
#        [14.9, 81. ],
#        [11.5, 68. ],
#        [ 9.2, 65. ],
#        [14.3, 56. ],
#        [11.5, 79. ],
#        [14.3, 80. ],
#        [13.8, 90. ],
#        [14.3, 79. ],
#        [ 5.7, 88. ],
#        [10.3, 68. ],
#        [ 6.3, 79. ],
#        [ 9.2, 66. ],
#        [ 6.9, 70. ],
#        [ 8.6, 86. ],
#        [ 6.9, 91. ],
#        [10.9, 71. ],
#        [ 9.7, 69. ],
#        [12.6, 75. ],
#        [12.6, 74. ],
#        [ 9.7, 80. ],
#        [ 8.6, 65. ],
#        [ 7.4, 67. ],
#        [10.3, 78. ],
#        [ 4.6, 83. ],
#        [ 8. , 75. ],
#        [11.5, 82. ],
#        [ 6.3, 77. ],
#        [14.9, 77. ],
#        [ 9.2, 85. ],
#        [14.9, 91. ],
#        [ 8. , 86. ],
#        [ 7.4, 82. ],
#        [ 8. , 76. ],
#        [ 7.4, 83. ],
#        [ 6.9, 74. ],
# ...

# %%
labels=y_train.iloc[:].values
labels
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1230-1052cd265a50> in <module>()
# ----> 1 labels=y_train.iloc[:].values
#       2 labels
#
# AttributeError: 'numpy.ndarray' object has no attribute 'iloc'

# %%
X=features
y=labels

# %%
from sklearn import  linear_model as lm
model=lm.LinearRegression()
results=model.fit(X,y)

# %%
prediction=model.predict(X)
accuracy=model.score(X,y)
print("Accuracy is",accuracy)

# %%
plt.scatter(y,prediction)
